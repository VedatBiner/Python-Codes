# %%
# kütüphane modülümüzü ekleyelim
from kutuphane import *

# %%
# Giriş Ekranı
print("""
*******************************************
Kütüphane Programına Hoş Geldiniz ... 
*******************************************
İşlemler : 
--------------------------
1. Kitapları Göster
2. Kitap Sorgulama 
3. Kitap Ekle
4. Kitap Sil
5. Baskı Yükselt
--------------------------
Çıkş için "q" ya basın
*******************************************
""")
# Out:
# *******************************************
# Kütüphane Programına Hoş Geldiniz ...
# *******************************************
# İşlemler :
# --------------------------
# 1. Kitapları Göster
# 2. Kitap Sorgulama
# 3. Kitap Ekle
# 4. Kitap Sil
# 5. Baskı Yükselt
# --------------------------
# Çıkş için "q" ya basın
# *******************************************

# %%
# Kütüphane sınıfı oluşturalım 
kutuphane = Kutuphane()

# %%
# Q basılana kadar işlem devam etsin
while True:
    islem = input("Yapacağınız işlem : ")
    if (islem == "q"):
        print("Program sonlandırılıyor ...")
        print("Yine bekleriz ...")
        kutuphane.baglantiyi_kes()
        break

    elif (islem == "1"): # Kitapları Gösterelim
        kutuphane.baglanti_olustur()
        kutuphane.kitaplari_goster()

    elif (islem == "2"): # Kitap sorgulama
        kutuphane.baglanti_olustur()
        isim = input("Hangi kitabı istiyorsunuz ? ")
        time.sleep(2)
        kutuphane.kitap_sorgula(isim)
        print("İstediğiniz Kitap : ", isim)

    elif (islem == "3"): # Kitap Ekleyelim
        isim = input("Kitap Adı : ")
        yazar = input("Yazar Adı : ")
        yayinevi = input("Yayınevi : ")
        tur = input("Kitap Türü : ")
        baski = int(input("Baskı : "))
        # Yeni kitap objesi oluşturalım
        yeni_kitap = Kitap(isim, yazar, yayinevi, tur, baski)
        print("Kitap ekleniyor ...")
        time.sleep(2)
        kutuphane.kitap_ekle(yeni_kitap)
        print("Kitap eklendi ...")

    elif (islem == "4"): # Kitap silme
        isim = input("Hangi kitabı silmek istiyorsunuz ? : (E/H)")
        cevap = input("Emin misiniz ? ")
        if (cevap == "e"): 
            print("Kitap Siliniyor ...")
            time.sleep(2)

    elif (islem == "5"): # Baskı yükselt
        isim = input("Hangi kitabın baskısını yükseltmek istiyorsunuz ? : ")
        print("Baskı yükseltiliyor ...")
        time.sleep(2)
        kutuphane.baski_yukselt(isim)
        print("Baskı yükseltildi ...")

    else:
        print("Geçersiz işlem !!!")
# Out:
# Böyle bir kitap bulunmuyor ...
# İstediğiniz Kitap :  Jaws
# Böyle bir kitap bulunmuyor ...
# İstediğiniz Kitap :  Dune
# Kitap İsmi : Yüzük Kardeşliği
# Yazar : J.R.R. Tolkien
# Yayınevi : Metis Edebiyat
# Tür : Fantastik
# Baskı : 12
#
# İstediğiniz Kitap :  Yüzük Kardeşliği
# Kitap ekleniyor ...
# Kitap eklendi ...
# Kitap İsmi : Yüzük Kardeşliği
# Yazar : J.R.R. Tolkien
# Yayınevi : Metis Edebiyat
# Tür : Fantastik
# Baskı : 12
#
# Kitap İsmi : İstanbul Hatırası
# Yazar : Ahmet Ümit
# Yayınevi : Everest
# Tür : Polisiye
# Baskı : 29
#
# Kitap İsmi : On Küçük Zenci
# Yazar : Agatha Cristie
# Yayınevi : Altın Kitaplar
# Tür : Polisiye
# Baskı : 10
#
# Kitap İsmi : Yüzük Kardeşliği
# Yazar : J.R.R. Tolkien
# Yayınevi : Metis Edebiyat
# Tür : Fantastik
# Baskı : 12
#
# Kitap İsmi : İstanbul Hatırası
# Yazar : Ahmet Ümit
# Yayınevi : Everest
# Tür : Polisiye
# Baskı : 29
#
# Kitap İsmi : On Küçük Zenci
# Yazar : Agatha Cristie
# Yayınevi : Altın Kitaplar
# Tür : Polisiye
# Baskı : 10
# ...
